# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from pandas_profiling import PandasProfile

# %%
train_data = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\BOOKS\kaggle\\train.csv")
train_data.head(10)
# Out:
#          customer_id  age           job  marital            education  \
# 0  customer_id_39075   31        admin.  married    university.degree
# 1  customer_id_34855   31    technician   single    university.degree
# 2   customer_id_7107   47   blue-collar  married             basic.6y
# 3  customer_id_31614   36      services  married    university.degree
# 4  customer_id_34878   34        admin.   single          high.school
# 5  customer_id_24606   48  entrepreneur  married    university.degree
# 6  customer_id_13094   34   blue-collar   single             basic.4y
# 7  customer_id_36912   34    technician   single  professional.course
# 8  customer_id_27834   39    unemployed   single    university.degree
# 9   customer_id_9302   40    technician   single  professional.course
#
#    default  housing     loan    contact month  ... campaign  pdays  previous  \
# 0       no       no       no   cellular   dec  ...        3    999         1
# ...

# %%
train_data.shape
# Out:
# (28831, 22)

# %%
train_data.isna().sum()
# Out:
# customer_id       0
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# subscribed        0
# dtype: int64

# %%
dict = {}
for i in list(train_data.columns):
    dict[i] = train_data[i].value_counts().shape[0]

pd.DataFrame(dict, index=["unique count"]).transpose()
# Out:
#                 unique count
# customer_id            28831
# age                       77
# job                       12
# marital                    4
# education                  8
# default                    3
# housing                    3
# loan                       3
# contact                    2
# month                     10
# day_of_week                5
# duration                1432
# campaign                  40
# pdays                     26
# previous                   8
# poutcome                   3
# emp_var_rate              10
# cons_price_idx            26
# cons_conf_idx             26
# euribor3m                312
# nr_employed               11
# subscribed                 2

# %%
train_data.head(2)
# Out:
#          customer_id  age         job  marital          education default  \
# 0  customer_id_39075   31      admin.  married  university.degree      no
# 1  customer_id_34855   31  technician   single  university.degree      no
#
#   housing loan    contact month  ... campaign  pdays  previous     poutcome  \
# 0      no   no   cellular   dec  ...        3    999         1      failure
# 1      no   no  telephone   may  ...        4    999         0  nonexistent
#
#    emp_var_rate cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 0         -2.97        46.3565         -23.10      1.711       5023.5
# 1         -1.77        46.4465         -32.34      2.252       5099.1
#
#    subscribed
# 0           0
# 1           0
#
# [2 rows x 22 columns]

# %%
train_data.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.003741  0.008758 -0.036666  0.027094
# duration       -0.003741  1.000000 -0.072445 -0.052064  0.020699
# campaign        0.008758 -0.072445  1.000000  0.050604 -0.077222
# pdays          -0.036666 -0.052064  0.050604  1.000000 -0.581918
# previous        0.027094  0.020699 -0.077222 -0.581918  1.000000
# emp_var_rate   -0.000595 -0.029512  0.154406  0.267267 -0.418479
# cons_price_idx  0.003682  0.006035  0.128875  0.069794 -0.199327
# cons_conf_idx   0.126321 -0.008210 -0.013231 -0.089671 -0.054665
# euribor3m       0.010074 -0.035028  0.138310  0.294894 -0.452338
# nr_employed    -0.018042 -0.047273  0.147386  0.373829 -0.498962
# subscribed      0.022599  0.399154 -0.070794 -0.326485  0.226691
#
#                 emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# age                -0.000595        0.003682       0.126321   0.010074
# ...

# %%
x=train_data.drop("subscribed", axis="columns")
y=train_data["subscribed"]
x.head(5)
# Out:
#          customer_id  age          job  marital          education  default  \
# 0  customer_id_39075   31       admin.  married  university.degree       no
# 1  customer_id_34855   31   technician   single  university.degree       no
# 2   customer_id_7107   47  blue-collar  married           basic.6y  unknown
# 3  customer_id_31614   36     services  married  university.degree       no
# 4  customer_id_34878   34       admin.   single        high.school       no
#
#   housing loan    contact month  ...   duration  campaign  pdays  previous  \
# 0      no   no   cellular   dec  ...   1.283333         3    999         1
# 1      no   no  telephone   may  ...   0.200000         4    999         0
# 2     yes   no  telephone   may  ...   4.616667         2    999         0
# 3      no   no   cellular   may  ...   1.166667         1    999         1
# 4      no   no   cellular   may  ...  19.683333         9    999         0
#
# ...

# %%
y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: subscribed, dtype: int64

# %%
pd.get_dummies(x)
# Out:
#        age   duration  campaign  pdays  previous  emp_var_rate  \
# 0       31   1.283333         3    999         1         -2.97
# 1       31   0.200000         4    999         0         -1.77
# 2       47   4.616667         2    999         0          1.13
# 3       36   1.166667         1    999         1         -1.77
# 4       34  19.683333         9    999         0         -1.77
# 5       48   1.300000         2    999         1         -0.07
# 6       34   2.366667         2    999         0          1.43
# 7       34   8.733333         1    999         0         -2.87
# 8       39   7.200000         1    999         0         -1.77
# 9       40   0.983333         3    999         0          1.43
# 10      43   6.100000         1    999         0         -1.77
# 11      55   2.533333         2    999         0          1.43
# 12      29   1.833333         1    999         0         -1.77
# 13      40   1.700000         1    999         0          1.43
# ...

# %%
x = pd.get_dummies(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 173)

# %%
# Logistic regression model
from sklearn.linear_model import LogisticRegression
logisticmodel = LogisticRegression()
logisticmodel.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
logisticmodel.predict(x_test)

# %%
logistic_prediction = logisticmodel.predict(x_test)

# %%
metrics.accuracy_score(y_test, logistic_prediction)

# %%
test_data = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\BOOKS\kaggle\\test.csv")
test_data.head(5)

# %%
test_data.drop(["customer_id"], axis = "columns", inplace =True)

# %%
test_data.head(2)

# %%
x= test_data
pd.get_dummies(x)
x=pd.get_dummies(x)

# %%
logisticmodel.predict(x)
my_prediction_1 = logisticmodel.predict(x)
my_prediction_1

# %%
df1 =pd.DataFrame(my_prediction_1)
df1.to_csv(r"C:\Users\LENOVO\Desktop\BOOKS\kaggle\sample_submission.csv")

# %%
#NAIVE BAYES MODEL

from sklearn.naive_bayes import GaussianNB

naivemodel = GaussianNB()
naivemodel.fit(x_train, y_train)

# %%
naivemodel.predict(x)
my_prediction_2 = naivemodel.predict(x)
my_prediction_2

# %%
X=train_data.drop("subscribed", axis="columns")
y=train_data["subscribed"]
X.head(2)

# %%
#RANDOM FOREST MODEL


from sklearn.ensemble import RandomForestClassifier

randomforestmodel = RandomForestClassifier()
randomforestmodel.fit(x_train, y_train)

# %%
df2 =pd.DataFrame(my_prediction_2)
df2.to_csv(r"C:\Users\LENOVO\Desktop\BOOKS\kaggle\randomforest.csv")

# %%
randomforestmodel_prediction = randomforestmodel.predict(x_test)

# %%
#you can call the randomforestmodel_prediction method to see the prediction

randomforestmodel_prediction

# %%
df2 =pd.DataFrame(randomforestmodel_prediction)
df2.to_csv(r"C:\Users\LENOVO\Desktop\BOOKS\kaggle\randomforest1.csv")

# %%
metrics.accuracy_score(y_test, randomforestmodel_prediction)
